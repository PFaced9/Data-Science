# %% [markdown]
# # Problem Statement:
# ### Given the e-commerce data, use k-means clustering algorithm to cluster customers with similar interest.

# %%
# Using KMeans Clustring Algorithm

# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Reading Dataset

# %%
data = pd.read_excel('cust_data.xlsx')

# %%
data.sample(10)
# Out:
#        Cust_ID Gender  Orders  Jordan  Gatorade  Samsung  Asus  Udis  \
# 11841    11842      F       0       0         0        1     0     0
# 14530    14531      F       2       0         0        2     0     0
# 17518    17519      M       7       0         0        0     0     0
# 17874    17875      F       1       0         0        0     0     0
# 1853      1854      F       9       0         0        5     0     0
# 24803    24804      M       8       0         0        0     0     0
# 5505      5506      F       1       0         0        0     0     2
# 23056    23057      F       9       0         0        0     0     0
# 1169      1170      F       0       0         0        0     0     0
# 5483      5484      F       6       0         0        0     0     0
#
#        Mondelez International  Wrangler  ...  LG  Dior  Scabal  \
# 11841                       0         0  ...   0     0       1
# 14530                       0         0  ...   0     1       1
# 17518                       0         0  ...   0     0       0
# 17874                       1         0  ...   0     2       0
# 1853                        0         0  ...   0     1       0
# 24803                       0         0  ...   0     0       0
# 5505                        0         0  ...   0     0       0
# 23056                       0         0  ...   0     0       3
# 1169                        0         0  ...   0     0       0
# 5483                        0         0  ...   0     0       0
#
#        Tommy Hilfiger  Hollister  Forever 21  Colavita  Microsoft  Jiffy mix  \
# 11841               1          0           0         0          0          1
# 14530               0          0           0         1          0          0
# 17518               0          0           0         0          0          0
# 17874               0          0           0         0          0          0
# 1853                0          0           0         0          0          0
# 24803               0          0           0         0          0          0
# 5505                0          0           0         0          0          0
# 23056               0          0           0         0          1          0
# 1169                0          0           0         0          0          0
# 5483                0          0           0         0          0          0
#
#        Kraft
# 11841      1
# 14530      0
# 17518      0
# 17874      0
# 1853       0
# 24803      0
# 5505       0
# 23056      0
# 1169       0
# 5483       0
#
# [10 rows x 38 columns]
